# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)

# %%
url = "http://ergast.com/api/f1/2008/5/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
type(data)
# Out:
# list

# %%
def get_racer_info(data):
    new_data=[]
    for racer in data:
        racer_dict={}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        
        racer_dict[racer_name]={
            'first_name':racer['Driver']['givenName'],
            'last_name':racer['Driver']['familyName'],
            'position':racer['position'],
            'wins':racer['wins'],
            'DOB':racer['Driver']['dateOfBirth'],
            'nationality':racer['Driver']['nationality'],
            'contructor':racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(data)
# Out:
# [{'Kimi Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'contructor': 'Ferrari'}},
#  {'Felipe Massa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'contructor': 'Ferrari'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'contructor': 'McLaren'}},
#  {'Robert Kubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'contructor': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year,r):
    url = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
#     if not response.ok:
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data likely the year or round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2022,4)
# Out:
# 'We had an error loading your data likely the year or round is not in the database'

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
import requests, json

help(requests)

url = "https://pokeapi.co/api/v2/pokemon"

response = requests.get(url)
print(response)

response.ok
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "https://pokeapi.co/api/v2/pokemon/bulbasaur"

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response.ok
# Out:
# True

# %%
response.json()
# Out:
# {'abilities': [{'ability': {'name': 'overgrow',
#     'url': 'https://pokeapi.co/api/v2/ability/65/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'chlorophyll',
#     'url': 'https://pokeapi.co/api/v2/ability/34/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 64,
#  'forms': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}],
#  'game_indices': [{'game_index': 153,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 153,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 153,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 1,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 1,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 1,
# ...

# %%
data = response.json()
data
# Out:
# {'abilities': [{'ability': {'name': 'overgrow',
#     'url': 'https://pokeapi.co/api/v2/ability/65/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'chlorophyll',
#     'url': 'https://pokeapi.co/api/v2/ability/34/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 64,
#  'forms': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}],
#  'game_indices': [{'game_index': 153,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 153,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 153,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 1,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 1,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 1,
# ...

# %%
def get_pkmn_info(data):
    
#     URL = f"https://pokeapi.co/api/v2/pokemon"
    
#     specific_link = url.format(data)
    
#     response = requests.get(specific_link)
    
#     data = response.json() 
    

    new_info = []
    
    for mon in data:
        mon_dict = {}
        mon_name = ['name']
        
        mon_dict[mon_name]={
            'name':mon['name'],
            'ability':mon['abilities']['ability']['name'],
            'basexp':mon['base_experience'],
            'spriteURL':mon['sprites']['front_shiny']
        }
        new_info.append(mon_dict)
    return new_info

get_pkmn_info(data)
    
#     response = requests.get(url)
    
#     if not response.json():
#         return "We had an error loading your data, this pokemon likely doesn't exist"
#     data = response.json()
#     return
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3776\470511637.py in <module>
#      25     return new_info
#      26
# ---> 27 get_pkmn_info(data)
#      28
#      29 #     response = requests.get(url)
#
# ~\AppData\Local\Temp\ipykernel_3776\470511637.py in get_pkmn_info(data)
#      17
#      18         mon_dict[mon_name]={
# ---> 19             'name':mon['name'],
#      20             'ability':mon['abilities']['ability']['name'],
#      21             'basexp':mon['base_experience'],
#
# TypeError: string indices must be integers

# %%
def get_pkmn_info_by_name(name):
    url = f"https://pokeapi.co/api/v2/pokemon/{info}"
    response = requests.get(url)
    
    if not response.json():
        return "We had an error loading your data"
    info = response.json()
    return get_pkmn_info(info)
# Out:
# {'count': 1279,
#  'next': 'https://pokeapi.co/api/v2/pokemon?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
# ...

# %%
import requests, json

# mewtwo="https://pokeapi.co/api/v2/pokemon/mew"
# mew = 'https://pokeapi.co/api/v2/pokemon/mewtwo'
# zoroark = 'https://pokeapi.co/api/v2/pokemon/zoroark'
# lucario = 'https://pokeapi.co/api/v2/pokemon/lucario'
glaceon = 'https://pokeapi.co/api/v2/pokemon/glaceon'

response = requests.get(glaceon)

# print(response)
# response.ok
response.json()

# ## MEW

# abilityName = response.json()['abilities'][1]['ability']['name']
# abilityName

# basexp = response.json()['base_experience']
# basexp

# shiny = response.json()["sprites"]['front_shiny']
# shiny

# attack = response.json()['stats'][1]['base_stat']
# attack

# hp = response.json()['stats'][0]['base_stat']
# hp

# defense = response.json()['stats'][2]['base_stat']
# defense

## MEWTWO

# abilityName = response.json()['abilities'][0]['ability']['name']
# abilityName

# basexp = response.json()['base_experience']
# basexp

# shiny = response.json()['sprites']['front_shiny']
# shiny

# attack = response.json()['stats'][1]['base_stat']
# attack

# hp = response.json()['stats'][0]['base_stat']
# hp

# defense = response.json()['stats'][2]['base_stat']
# defense

## ZOROARK

# abilityName = response.json()['abilities'][0]['ability']['name']
# abilityName

# basexp = response.json()['base_experience']
# basexp

# shiny = response.json()['sprites']['front_shiny']
# shiny

# attack = response.json()['stats'][1]['base_stat']
# attack

# hp = response.json()['stats'][0]['base_stat']
# hp

# defense = response.json()['stats'][2]['base_stat']
# defense

#lucario

# abilityName = response.json()['abilities'][2]['ability']['name']
# abilityName

# basexp = response.json()['base_experience']
# basexp

# shiny = response.json()['sprites']['front_shiny']
# shiny

# attack = response.json()['stats'][1]['base_stat']
# attack

# hp = response.json()['stats'][0]['base_stat']
# hp

# defense = response.json()['stats'][2]['base_stat']
# defense

## glaceon
abilityName = response.json()['abilities'][0]['ability']['name']
print(f'ability name: {abilityName}')

basexp = response.json()['base_experience']
print(f'base experience: {basexp}')

shiny = response.json()['sprites']['front_shiny']
print(f'shiny: {shiny}')

attack = response.json()['stats'][1]['base_stat']
print(f'attack: {attack}')

hp = response.json()['stats'][0]['base_stat']
print(f'hitpoints: {hp}')

defense = response.json()['stats'][2]['base_stat']
print(f'defense: {defense}')
# Out:
# ability name: snow-cloak
# base experience: 184
# shiny: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/471.png
# attack: 60
# hitpoints: 65
# defense: 110
